# %%
import pandas as pd

# %%
#create columns using Series function

Name = pd.Series(['Dhara','Prapti','Devarshi','Het','Priyank'])
Salary = pd.Series([25000,30000,28000,35000,30000])

# %%
result = pd.DataFrame({'Name':Name,'Salary':Salary})

# %%
result.hist('Salary')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f79b48d9290>]],
#       dtype=object)

# %%
result["2000 Added"] = result["Salary"] + 2000

# %%
result
# Out:
#        Name  Salary  adjusted  2000 Added
# 0     Dhara   25000     27000       27000
# 1    Prapti   30000     32000       32000
# 2  Devarshi   28000     30000       30000
# 3       Het   35000     37000       37000
# 4   Priyank   30000     32000       32000

# %%
#starting value of particular cell

result['adjusted'][1]
# Out:
# 32000

# %%
#modify the cell

result.at[0,'adjusted'] = result['adjusted'][1]+500
result
# Out:
#        Name  Salary  adjusted  2000 Added
# 0     Dhara   25000     33010       27000
# 1    Prapti   30000     32510       32000
# 2  Devarshi   28000     33010       30000
# 3       Het   35000     37000       37000
# 4   Priyank   30000     32000       32000

# %%
#create copy

copy_result = result.copy()

# %%
copy_result
# Out:
#        Name  Salary  adjusted  2000 Added
# 0     Dhara   25000     33010       27000
# 1    Prapti   30000     32510       32000
# 2  Devarshi   28000     33010       30000
# 3       Het   35000     37000       37000
# 4   Priyank   30000     32000       32000

# %%
result
# Out:
#        Name  Salary  adjusted  2000 Added
# 0     Dhara   25000     33010       27000
# 1    Prapti   30000     32510       32000
# 2  Devarshi   28000     33010       30000
# 3       Het   35000     37000       37000
# 4   Priyank   30000     32000       32000

# %%
#memory usage of each column in bytes

result.memory_usage(deep=True)
# Out:
# Index         128
# Name          314
# Salary         40
# adjusted       40
# 2000 Added     40
# dtype: int64

# %%
Product_Name = pd.Series(['Pen','Phone','Watch','Watch','Laptop'])
Price = pd.Series([25,25000,10000,5000,52000])
new_data_Frame=  pd.DataFrame({'Product Name':Product_Name,'Product Price':Price})

# %%
new_data_Frame
# Out:
#   Product Name  Product Price
# 0          Pen             25
# 1        Phone          25000
# 2        Watch          10000
# 3        Watch           5000
# 4       Laptop          52000

# %%
#remove duplicate rows

new_data_Frame.drop_duplicates(inplace=True)

# %%
new_data_Frame
# Out:
#   Product Name  Product Price
# 0          Pen             25
# 1        Phone          25000
# 2        Watch          10000
# 3        Watch           5000
# 4       Laptop          52000

# %%
#merge 2 data frames

Name = pd.Series(['Dhara','Prapti','Devarshi','Het','Priyank'])
Age = pd.Series([25,26,27,28,23])

Student_Details=  pd.DataFrame({'Name':Name,'Age':Age})
result.merge(Student_Details, on='Name', how='left')
# Out:
#        Name  Salary  adjusted  2000 Added  Age
# 0     Dhara   25000     33010       27000   25
# 1    Prapti   30000     32510       32000   26
# 2  Devarshi   28000     33010       30000   27
# 3       Het   35000     37000       37000   28
# 4   Priyank   30000     32000       32000   23

# %%
print(result.sort_values(by='Name', inplace=False))
# Out:
#        Name  Salary  adjusted  2000 Added
# 2  Devarshi   28000     33010       30000
# 0     Dhara   25000     33010       27000
# 3       Het   35000     37000       37000
# 1    Prapti   30000     32510       32000
# 4   Priyank   30000     32000       32000

# %%
# All read_file and to_file functions are under Data I/O

#Preview functions are those functions that only shows data as it is in the file or in Data Frame

#Data Cleansing Are the functions that clears the field that is not needed in the file

#Data Transformation is change the value of column or row or whole dataframe
